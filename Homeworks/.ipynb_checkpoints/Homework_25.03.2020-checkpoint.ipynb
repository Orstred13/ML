# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, KFold, GridSearchCV, RandomizedSearchCV

from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
seed = 42
np.random.seed(seed)

# %%
data = pd.read_csv('train.csv')

# %%
y_raw = data['Survived']
X_raw = data.drop(['Survived'], axis=1)

# %%
drop = ['PassengerId', 'Name', 'Ticket', 'Cabin', 'Embarked']

# %%
X_raw.drop(columns=drop, inplace=True)

# %%
def binarize(x):
    if x == 'female':
        return 1
    else:
        return 0

# %%
X_raw['Sex'] = X_raw['Sex'].apply(lambda x: binarize(x))

# %%
X_raw['Age'].fillna(X_raw['Age'].median(), inplace=True)

# %%
X, X_test, y, y_test = train_test_split(X_raw, y_raw, test_size=0.15, 
                                                    random_state=seed)

# %%
from IPython.display import SVG
from graphviz import Source
from IPython.display import display
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier(criterion='entropy', 
                               max_depth=3, min_samples_leaf=10,
                              min_samples_split=10)
model.fit(X, y)


plt.figure(figsize=(13, 5))
tree.plot_tree(model, fontsize=10, feature_names=list(X), filled=True);

# %%
model.score(X,y)
# Out:
# 0.8229854689564069

# %% [markdown]
# Окей, вроде всё работает

# %%
model.fit(X, y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=3,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=10, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
# %%time
parametrs = {'criterion': ['gini', 'entropy'], 'max_depth': range(1, 10), 'min_samples_split': range(2, 100), 'min_samples_leaf': range(1, 100)}
model = DecisionTreeClassifier()
clf = GridSearchCV(model, parametrs)
clf.fit(X, y)
# Out:
# C:\Users\orstr\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# Wall time: 45min 49s
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=DecisionTreeClassifier(class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features=None,
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
# ...

# %%
# %%time
parametrs = {'max_features': ['auto', 'sqrt', 'log2', None], 'criterion': ['gini', 'entropy'], 'max_depth': range(1, 10), 'min_samples_split': range(2, 10), 'min_samples_leaf': range(1, 10)}
model = DecisionTreeClassifier()
clf = GridSearchCV(model, parametrs)
clf.fit(X, y)
#решил уменьшить range и добавить новые параметры
# Out:
# C:\Users\orstr\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# Wall time: 1min 18s
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=DecisionTreeClassifier(class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features=None,
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
# ...

# %% [markdown]
# Ооооокееееей, мб не стоило ставить так много всего, а то я уже начал засыпать

# %%
clf.cv_results_['mean_test_score'].max()
# Out:
# 0.8229854689564069

# %% [markdown]
# Ну, результат вроде неплохой, посмотрим при каких параметрах это всё получилось

# %%
clf.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 9,
#  'max_features': 'log2',
#  'min_samples_leaf': 3,
#  'min_samples_split': 9}

# %% [markdown]
# Внезапно, но если добавить критерии, то энтропия показывает себя лучше

# %% [markdown]
# Ещё тут выяснил, что при критериях Gini точность выше и для наилучшего варианта у них гиперпараметры отличаются
# P.S. Не знаю, почему я сразу не сделал перебор по параметрам тоже, но чуть позже я это сделал
# P.S.S. Не знаю, почему я это пишу, мне просто скучно, пока я жду, когда он это всё переберёт, недеюсь это тоже вас немног развеселит, пока будете проверять)

# %%
model = DecisionTreeClassifier(criterion='entropy', 
                               max_depth=9, min_samples_leaf=3,
                              min_samples_split=9, max_features='log2')

model.fit(X, y)


plt.figure(figsize=(13, 5))
tree.plot_tree(model, fontsize=10, feature_names=list(X), filled=True);

# %%
model.score(X,y)
# Out:
# 0.8494055482166446

# %% [markdown]
# Правда вот тут немного не понимаю, почему значения отличаются, не могли бы вы мне пояснить?)

# %% [markdown]
# Окей, теперь попробуем RandomizedSearchcv

# %%
# %%time
parametrs = {'max_features': ['auto', 'sqrt', 'log2', None],'criterion': ['gini', 'entropy'], 'max_depth': range(1, 10), 'min_samples_split': range(2, 10), 'min_samples_leaf': range(1, 10)}
model = DecisionTreeClassifier()
clf = RandomizedSearchCV(model, parametrs)
clf.fit(X, y)
# Out:
# Wall time: 181 ms
# C:\Users\orstr\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# RandomizedSearchCV(cv='warn', error_score='raise-deprecating',
#                    estimator=DecisionTreeClassifier(class_weight=None,
#                                                     criterion='gini',
#                                                     max_depth=None,
#                                                     max_features=None,
#                                                     max_leaf_nodes=None,
#                                                     min_impurity_decrease=0.0,
#                                                     min_impurity_split=None,
#                                                     min_samples_leaf=1,
# ...

# %%
clf.cv_results_['mean_test_score'].max()
# Out:
# 0.8058124174372523

# %%
clf.best_params_
# Out:
# {'min_samples_split': 4,
#  'min_samples_leaf': 7,
#  'max_features': 'log2',
#  'max_depth': 6,
#  'criterion': 'entropy'}

# %% [markdown]
# В RandomizedSearchCV лучше не делать большой разлёт данных как в первом случае, а то каждый раз будут разные результаты
# Или я не прав?
# Просто, как я понял, он вибирает какое-то фиксированное количество настроек.
# Хотя это может быть и полезно, если большое количество данных и важно время.

# %% [markdown]
# В любом случае результат хуже, но зато гораздо быстрее

# %%
model = DecisionTreeClassifier(criterion='entropy', 
                               max_depth=6, min_samples_leaf=7,
                              min_samples_split=4, max_features='log2')

model.fit(X, y)


plt.figure(figsize=(13, 8))
tree.plot_tree(model, fontsize=10, feature_names=list(X), filled=True);

# %%
model.score(X, y)
# Out:
# 0.8322324966974901

# %% [markdown]
# Тут перебор справился лучше(что и следовало ожидать).
# Посмотрим, что там с логистической регресией.

# %%
import warnings
warnings. filterwarnings('ignore')

# %%
# %%time
parametrs = {'penalty':['l1', 'l2'],'C': range(1, 100), 'fit_intercept': [True, False]}
model = LogisticRegression()
clf = GridSearchCV(model, parametrs)
clf.fit(X, y)
# Out:
# Wall time: 7.51 s
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                           fit_intercept=True,
#                                           intercept_scaling=1, l1_ratio=None,
#                                           max_iter=100, multi_class='warn',
#                                           n_jobs=None, penalty='l2',
#                                           random_state=None, solver='warn',
#                                           tol=0.0001, verbose=0,
#                                           warm_start=False),
#              iid='warn', n_jobs=None,
#              param_grid={'C': range(1, 100), 'fit_intercept': [True, False],
#                          'penalty': ['l1', 'l2']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %% [markdown]
# Пытался ещё с различными солверами, но большенство из них ругается на пенальти, пришлось отказаться от них

# %%
clf.cv_results_['mean_test_score'].max()
# Out:
# 0.7965653896961691

# %%
clf.best_params_
# Out:
# {'C': 2, 'fit_intercept': True, 'penalty': 'l2'}

# %%
model = model = LogisticRegression(C= 2, fit_intercept= True, penalty= 'l2')
model.fit(X,y)
# Out:
# LogisticRegression(C=2, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
model.score(X,y)
# Out:
# 0.8031704095112285

# %%
# %%time
parametrs = {'penalty':['l1', 'l2'],'C': range(1, 100), 'fit_intercept': [True, False]}
model = LogisticRegression()
clf = RandomizedSearchCV(model, parametrs)
clf.fit(X, y)
# Out:
# Wall time: 232 ms
# RandomizedSearchCV(cv='warn', error_score='raise-deprecating',
#                    estimator=LogisticRegression(C=1.0, class_weight=None,
#                                                 dual=False, fit_intercept=True,
#                                                 intercept_scaling=1,
#                                                 l1_ratio=None, max_iter=100,
#                                                 multi_class='warn', n_jobs=None,
#                                                 penalty='l2', random_state=None,
#                                                 solver='warn', tol=0.0001,
#                                                 verbose=0, warm_start=False),
#                    iid='warn', n_iter=10, n_jobs=None,
#                    param_distributions={'C': range(1, 100),
#                                         'fit_intercept': [True, False],
#                                         'penalty': ['l1', 'l2']},
# ...

# %%
clf.cv_results_['mean_test_score'].max()
# Out:
# 0.7952443857331571

# %%
clf.best_params_
# Out:
# {'penalty': 'l2', 'fit_intercept': False, 'C': 46}

# %%
model = model = LogisticRegression(C= 46, fit_intercept= False, penalty= 'l2')
model.fit(X,y)
# Out:
# LogisticRegression(C=46, class_weight=None, dual=False, fit_intercept=False,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
model.score(X,y)
# Out:
# 0.7952443857331571

# %% [markdown]
# Тут даже получились одинаковые результаты, но всё же дерево решений показывает более лучший результат.
# Пойду посплю теперь)

# %%
data = pd.read_csv('train.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
labelencoder = LabelEncoder()
colomn = ['Sex', 'Name', 'Ticket', 'Embarked']
for colomn in data[colomn]:
    labelencoder.fit(data[colomn])
    data[colomn] = labelencoder.transform(data[colomn])

# %% [markdown]
# Возникли проблемы с Cabin и Embarked, пока оставлю и посмотрю, что там по Nan

# %%
data.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# Ну, в Age можно как и раньше заменить медианой, в Embarked убрать эти 2 записи(не думаю, что они сыграют большую роль), а вот Cabin можно вообще убрать. Ну или вообще всё заменить -1 какой-нибудь, посмотрим, какой вариант лучше будет

# %%
data.drop(columns = ['Cabin'], inplace=True)

# %%
data['Age'].fillna(data['Age'].median(), inplace=True)

# %%
data.dropna(inplace = True)

# %% [markdown]
# Ну, вот теперь с этим можно работать

# %%
y_raw = data['Survived']
X_raw = data.drop(['Survived'], axis=1)

# %%
X, X_test, y, y_test = train_test_split(X_raw, y_raw, test_size=0.15, 
                                                    random_state=seed)

# %%
model = DecisionTreeClassifier(criterion='entropy', 
                               max_depth=9, min_samples_leaf=3,
                              min_samples_split=9, max_features='log2')

model.fit(X, y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=9,
#                        max_features='log2', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=3, min_samples_split=9,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
model.score(X,y)
# Out:
# 0.8754966887417218

# %% [markdown]
# Ооооо, точность значительно увеличилась, до этого была 0.8494055482166446

# %%
model = model = LogisticRegression(C= 2, fit_intercept= True, penalty= 'l2')
model.fit(X,y)
# Out:
# C:\Users\orstr\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=2, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
model.score(X,y)
# Out:
# 0.8013245033112583

# %% [markdown]
# Нууу, тут как-то совсем всё плохо, предыдущий результат был 0.8031704095112285

# %% [markdown]
# Я очень долго мучался с OneHotEncoder, но так и не понял, как его использовать(((

# %% [markdown]
# Хотелось бы позадавать вам вопросы по этому поводу

# %% [markdown]
# Выздоравливайте поскорее)
