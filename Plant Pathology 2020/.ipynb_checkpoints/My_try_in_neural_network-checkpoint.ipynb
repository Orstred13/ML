# %%
from matplotlib import pyplot as plt
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, GlobalAveragePooling2D
import keras

import pandas as pd
# Out:
# Using TensorFlow backend.

# %%
img = plt.imread('images/Train_0.jpg')
print(img.shape)
plt.imshow(img)

# %%
test = pd.read_csv('test.csv')
train = pd.read_csv('train.csv')

# %%
train

# %%
test

# %%
sample_submission.head()

# %%
img

# %%
train.sum(axis=0)

# %% [markdown]
# Тут проблема с multiple_diseases, нейронка будет плохо определять этот класс, как вариант можно как нагенерировать(поворотами и сдвигами) фотографий именно этого класса, но я не совсем понимаю, как это сделать

# %%
train_images = []
for name in train['image_id'] :
    path = 'images/'+name+'.jpg'
    image = plt.imread(path)
    train_images.append(image)

# %%
train_images[0].shape

# %%
X = np.ndarray(shape=(len(train_images),1365,2048,3),dtype=np.float32)

# %% [markdown]
# Нуууууу, столько у меня места явно нет, поэтому можно попытаться уменьшить разрешения картинок

# %% [markdown]
# У pyplot я не нашёл, как можно изменить разрешение картинок, поэтому использую OpenCV

# %%
import cv2

# %%
train_images = []
img_size = 224
for name in train['image_id'] :
    path = 'images/'+name+'.jpg'
    image = plt.imread(path)
    image=cv2.resize(image,(img_size,img_size),interpolation=cv2.INTER_AREA)
    train_images.append(image)

# %%
train_images[1].shape
# Out:
# (224, 224, 3)

# %%
X = np.ndarray(shape=(len(train_images),img_size,img_size,3),dtype=np.float32)

# %%
for i,image in enumerate(train_images) :
    X[i] = image

# %%
X = X/255

# %%
plt.imshow(X[0])

# %%
X.shape
# Out:
# (1821, 224, 224, 3)

# %% [markdown]
# Ура, не знаю почему, но именно эта часть у меня заняла 1.5 дня...

# %% [markdown]
# Теперь быстренько с тестовыми разбираемся

# %%
test_images = []
for name in test['image_id'] :
    path = 'images/'+name+'.jpg'
    image = plt.imread(path)
    image=cv2.resize(image,(img_size,img_size),interpolation=cv2.INTER_AREA)
    test_images.append(image)

# %%
y = train.drop('image_id',axis=1)
y = np.array(y)
y.shape
# Out:
# (1821, 4)

# %%
X_test_kaggle = np.ndarray(shape=(len(test_images),img_size,img_size,3),dtype=np.float32)

for i,image in enumerate(test_images) :
    X_test_kaggle[i]=image

X_test_kaggle = X_test_kaggle / 255

# %%
X_test_kaggle.shape
# Out:
# (1821, 224, 224, 3)

# %%
plt.imshow(X_test_kaggle[3])

# %%
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization

# %%
model = Sequential()
   
    
model.add(Conv2D(64, (3, 3), activation='relu', input_shape=(64, 64, 3), padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))    
model.add(Dropout(0.3))
    

model.add(Conv2D(128,kernel_size=(3,3),padding='same',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))   
model.add(Dropout(0.3))


model.add(Conv2D(256,kernel_size=(3,3),padding='same',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))    
model.add(Dropout(0.3))



model.add(Flatten())
model.add(Dense(512,activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(64,activation='relu'))
model.add(Dense(4,activation='softmax'))


model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.summary()

# %%
predict = model.predict(X_test_kaggle)

# %%
df_pred  = pd.DataFrame(predict, columns = ['healthy','multiple_diseases','rust','scab'])
results = {'image_id' : test.image_id,
            'healthy' : df_pred.healthy,
            'multiple_diseases' : df_pred.multiple_diseases,
            'rust' : df_pred.rust,
            'scab' : df_pred.scab
          }
df_results_cnn = pd.DataFrame(results)
df_results_cnn.to_csv('submission.csv',index=False)

# %% [markdown]
# Ну, результат получился не самым лучшим, попытаемся улучшить всё это дело

# %%
X = (X - X.mean()) / X.std() #Внезапно вспомнил про нормализацию

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(
      rotation_range=60,
      width_shift_range=0.2,
      height_shift_range=0.2,
      horizontal_flip=True,
      fill_mode='nearest')

# %%
train_datagen.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-a16e65196b5a> in <module>
# ----> 1 train_datagen.fit(X_train, y_train)
#
# F:\Anaconda\lib\site-packages\keras_preprocessing\image\image_data_generator.py in fit(self, x, augment, rounds, seed)
#     944
#     945         x = np.copy(x)
# --> 946         if augment:
#     947             ax = np.zeros(
#     948                 tuple([rounds * x.shape[0]] + list(x.shape)[1:]),
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
model.fit_generator(train_datagen.flow(X_train, y_train, batch_size=32),
                    epochs=40, validation_data= (X_test,y_test))

# %% [markdown]
# Ну я уже не знаю, что делать, добавлю кросс валидацию

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# Ну всё, остаётся только уже готовую брать, например NasNet или VGG16

# %%
from keras.applications import VGG16

vgg_conv = VGG16(weights='imagenet', include_top=False, input_shape=(64, 64, 3))

# %%
model = Sequential()

model.add(vgg_conv)
model.add(Flatten())
model.add(Dense(512, activation='relu', )) 
model.add(Dense(64, activation='relu'))
model.add(Dense(4, activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.fit_generator(train_datagen.flow(X_train, y_train, batch_size=32),
                    epochs=40, validation_data= (X_test,y_test))

# %%
import tensorflow as tf
import tensorflow.keras.layers as L
import efficientnet.tfkeras as efn

# %%
model = tf.keras.Sequential([
        efn.EfficientNetB7(
            input_shape=(64, 64, 3),
            weights='imagenet',
            include_top=False
        ),
        L.GlobalAveragePooling2D(),
        L.Dense(4, activation='softmax')
    ])
        
model.compile(
        optimizer='adam',
        loss = 'categorical_crossentropy',
        metrics=['categorical_accuracy'])

# %%
model.fit_generator(train_datagen.flow(X_train, y_train, batch_size=32),
                    epochs=40, validation_data= (X_test,y_test))

# %%
model.fit(X, y,
          epochs=40,
          batch_size=32, validation_split=0.1)

# %%
from keras.applications import NASNetMobile



#Load the VGG model
nasnet = NASNetMobile(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# %%
for layer in nasnet.layers:
    layer.trainable = False

# %%
model = Sequential()

model.add(nasnet)
model.add(Flatten())

model.add(Dense(128, activation='relu', )) 
model.add(Dense(32, activation='relu'))
model.add(Dense(4, activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.fit_generator(train_datagen.flow(X_train, y_train, batch_size=32),
                    epochs=20, validation_data= (X_test,y_test))
# Out:
# Epoch 1/20
# 52/52 [==============================] - 110s 2s/step - loss: 2.0446 - accuracy: 0.5604 - val_loss: 1.1378 - val_accuracy: 0.5574
# Epoch 2/20
# 52/52 [==============================] - 111s 2s/step - loss: 0.9576 - accuracy: 0.6960 - val_loss: 2.0308 - val_accuracy: 0.4590
# Epoch 3/20
#  4/52 [=>............................] - ETA: 1:32 - loss: 1.0548 - accuracy: 0.6484
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-3d431769e5c3> in <module>
#       1 model.fit_generator(train_datagen.flow(X_train, y_train, batch_size=32),
# ----> 2                     epochs=20, validation_data= (X_test,y_test))
#
# F:\Anaconda\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# F:\Anaconda\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1730             use_multiprocessing=use_multiprocessing,
#    1731             shuffle=shuffle,
# -> 1732             initial_epoch=initial_epoch)
#    1733
#    1734     @interfaces.legacy_generator_methods_support
#
# F:\Anaconda\lib\site-packages\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     218                                             sample_weight=sample_weight,
#     219                                             class_weight=class_weight,
# --> 220                                             reset_metrics=False)
#     221
#     222                 outs = to_list(outs)
#
# F:\Anaconda\lib\site-packages\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1512             ins = x + y + sample_weights
#    1513         self._make_train_function()
# -> 1514         outputs = self.train_function(ins)
#    1515
#    1516         if reset_metrics:
#
# F:\Anaconda\lib\site-packages\tensorflow_core\python\keras\backend.py in __call__(self, inputs)
#    3725         value = math_ops.cast(value, tensor.dtype)
#    3726       converted_inputs.append(value)
# -> 3727     outputs = self._graph_fn(*converted_inputs)
#    3728
#    3729     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# F:\Anaconda\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    1549       TypeError: For invalid positional/keyword argument combinations.
#    1550     """
# -> 1551     return self._call_impl(args, kwargs)
#    1552
#    1553   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# F:\Anaconda\lib\site-packages\tensorflow_core\python\eager\function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1589       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1590           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1591     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1592
#    1593   def _filtered_call(self, args, kwargs):
#
# F:\Anaconda\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# F:\Anaconda\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# F:\Anaconda\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
from keras.applications.inception_v3 import InceptionV3
from keras.models import Model
from keras.layers import Dense, GlobalAveragePooling2D
from keras import backend as K

# %%
base_model = InceptionV3(weights='imagenet', include_top=False)


x = base_model.output
x = GlobalAveragePooling2D()(x)

x = Dense(1024, activation='relu')(x)

predictions = Dense(4, activation='softmax')(x)
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.5/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 211s 2us/step

# %%
# this is the model we will train
model = Model(inputs=base_model.input, outputs=predictions)

# first: train only the top layers (which were randomly initialized)
# i.e. freeze all convolutional InceptionV3 layers
for layer in base_model.layers:
    layer.trainable = False

# compile the model (should be done *after* setting layers to non-trainable)
model.compile(optimizer='rmsprop', loss='categorical_crossentropy')

# %%
# train the model on the new data for a few epochs
model.fit_generator(train_datagen.flow(X_train, y_train, batch_size=32),
                    epochs=5, validation_data= (X_test,y_test))
# Out:
# Epoch 1/5
# 52/52 [==============================] - 112s 2s/step - loss: 2.1517 - val_loss: 2.3655
# Epoch 2/5
# 52/52 [==============================] - 115s 2s/step - loss: 1.1139 - val_loss: 2.1045
# Epoch 3/5
# 52/52 [==============================] - 116s 2s/step - loss: 1.0259 - val_loss: 2.2858
# Epoch 4/5
# 52/52 [==============================] - 109s 2s/step - loss: 0.9055 - val_loss: 1.6987
# Epoch 5/5
# 52/52 [==============================] - 128s 2s/step - loss: 0.8694 - val_loss: 1.9637

# %%
# at this point, the top layers are well trained and we can start fine-tuning
# convolutional layers from inception V3. We will freeze the bottom N layers
# and train the remaining top layers.

# let's visualize layer names and layer indices to see how many layers
# we should freeze:
for i, layer in enumerate(base_model.layers):
   print(i, layer.name)
# Out:
# 0 input_3
# 1 conv2d_1
# 2 batch_normalization_1
# 3 activation_377
# 4 conv2d_2
# 5 batch_normalization_2
# 6 activation_378
# 7 conv2d_3
# 8 batch_normalization_3
# 9 activation_379
# 10 max_pooling2d_1
# 11 conv2d_4
# 12 batch_normalization_4
# 13 activation_380
# 14 conv2d_5
# 15 batch_normalization_5
# 16 activation_381
# 17 max_pooling2d_2
# 18 conv2d_9
# 19 batch_normalization_9
# 20 activation_385
# 21 conv2d_7
# 22 conv2d_10
# 23 batch_normalization_7
# 24 batch_normalization_10
# 25 activation_383
# 26 activation_386
# 27 average_pooling2d_1
# 28 conv2d_6
# 29 conv2d_8
# 30 conv2d_11
# 31 conv2d_12
# 32 batch_normalization_6
# 33 batch_normalization_8
# 34 batch_normalization_11
# 35 batch_normalization_12
# 36 activation_382
# 37 activation_384
# 38 activation_387
# 39 activation_388
# 40 mixed0
# 41 conv2d_16
# 42 batch_normalization_16
# 43 activation_392
# 44 conv2d_14
# 45 conv2d_17
# 46 batch_normalization_14
# 47 batch_normalization_17
# 48 activation_390
# 49 activation_393
# 50 average_pooling2d_2
# 51 conv2d_13
# 52 conv2d_15
# 53 conv2d_18
# 54 conv2d_19
# 55 batch_normalization_13
# 56 batch_normalization_15
# 57 batch_normalization_18
# 58 batch_normalization_19
# 59 activation_389
# 60 activation_391
# 61 activation_394
# 62 activation_395
# 63 mixed1
# 64 conv2d_23
# 65 batch_normalization_23
# 66 activation_399
# 67 conv2d_21
# 68 conv2d_24
# 69 batch_normalization_21
# 70 batch_normalization_24
# 71 activation_397
# 72 activation_400
# 73 average_pooling2d_3
# 74 conv2d_20
# 75 conv2d_22
# 76 conv2d_25
# 77 conv2d_26
# 78 batch_normalization_20
# 79 batch_normalization_22
# 80 batch_normalization_25
# 81 batch_normalization_26
# 82 activation_396
# 83 activation_398
# 84 activation_401
# 85 activation_402
# 86 mixed2
# 87 conv2d_28
# 88 batch_normalization_28
# 89 activation_404
# 90 conv2d_29
# 91 batch_normalization_29
# 92 activation_405
# 93 conv2d_27
# 94 conv2d_30
# 95 batch_normalization_27
# 96 batch_normalization_30
# 97 activation_403
# 98 activation_406
# 99 max_pooling2d_3
# 100 mixed3
# 101 conv2d_35
# 102 batch_normalization_35
# 103 activation_411
# 104 conv2d_36
# 105 batch_normalization_36
# 106 activation_412
# 107 conv2d_32
# 108 conv2d_37
# 109 batch_normalization_32
# 110 batch_normalization_37
# 111 activation_408
# 112 activation_413
# 113 conv2d_33
# 114 conv2d_38
# 115 batch_normalization_33
# 116 batch_normalization_38
# 117 activation_409
# 118 activation_414
# 119 average_pooling2d_4
# 120 conv2d_31
# 121 conv2d_34
# 122 conv2d_39
# 123 conv2d_40
# 124 batch_normalization_31
# 125 batch_normalization_34
# 126 batch_normalization_39
# 127 batch_normalization_40
# 128 activation_407
# 129 activation_410
# 130 activation_415
# 131 activation_416
# 132 mixed4
# 133 conv2d_45
# 134 batch_normalization_45
# 135 activation_421
# 136 conv2d_46
# 137 batch_normalization_46
# 138 activation_422
# 139 conv2d_42
# 140 conv2d_47
# 141 batch_normalization_42
# 142 batch_normalization_47
# 143 activation_418
# 144 activation_423
# 145 conv2d_43
# 146 conv2d_48
# 147 batch_normalization_43
# 148 batch_normalization_48
# 149 activation_419
# 150 activation_424
# 151 average_pooling2d_5
# 152 conv2d_41
# 153 conv2d_44
# 154 conv2d_49
# 155 conv2d_50
# 156 batch_normalization_41
# 157 batch_normalization_44
# 158 batch_normalization_49
# 159 batch_normalization_50
# 160 activation_417
# 161 activation_420
# 162 activation_425
# 163 activation_426
# 164 mixed5
# 165 conv2d_55
# 166 batch_normalization_55
# 167 activation_431
# 168 conv2d_56
# 169 batch_normalization_56
# 170 activation_432
# 171 conv2d_52
# 172 conv2d_57
# 173 batch_normalization_52
# 174 batch_normalization_57
# 175 activation_428
# 176 activation_433
# 177 conv2d_53
# 178 conv2d_58
# 179 batch_normalization_53
# 180 batch_normalization_58
# 181 activation_429
# 182 activation_434
# 183 average_pooling2d_6
# 184 conv2d_51
# 185 conv2d_54
# 186 conv2d_59
# 187 conv2d_60
# 188 batch_normalization_51
# 189 batch_normalization_54
# 190 batch_normalization_59
# 191 batch_normalization_60
# 192 activation_427
# 193 activation_430
# 194 activation_435
# 195 activation_436
# 196 mixed6
# 197 conv2d_65
# 198 batch_normalization_65
# 199 activation_441
# 200 conv2d_66
# 201 batch_normalization_66
# 202 activation_442
# 203 conv2d_62
# 204 conv2d_67
# 205 batch_normalization_62
# 206 batch_normalization_67
# 207 activation_438
# 208 activation_443
# 209 conv2d_63
# 210 conv2d_68
# 211 batch_normalization_63
# 212 batch_normalization_68
# 213 activation_439
# 214 activation_444
# 215 average_pooling2d_7
# 216 conv2d_61
# 217 conv2d_64
# 218 conv2d_69
# 219 conv2d_70
# 220 batch_normalization_61
# 221 batch_normalization_64
# 222 batch_normalization_69
# 223 batch_normalization_70
# 224 activation_437
# 225 activation_440
# 226 activation_445
# 227 activation_446
# 228 mixed7
# 229 conv2d_73
# 230 batch_normalization_73
# 231 activation_449
# 232 conv2d_74
# 233 batch_normalization_74
# 234 activation_450
# 235 conv2d_71
# 236 conv2d_75
# 237 batch_normalization_71
# 238 batch_normalization_75
# 239 activation_447
# 240 activation_451
# 241 conv2d_72
# 242 conv2d_76
# 243 batch_normalization_72
# 244 batch_normalization_76
# 245 activation_448
# 246 activation_452
# 247 max_pooling2d_4
# 248 mixed8
# 249 conv2d_81
# 250 batch_normalization_81
# 251 activation_457
# 252 conv2d_78
# 253 conv2d_82
# 254 batch_normalization_78
# 255 batch_normalization_82
# 256 activation_454
# 257 activation_458
# 258 conv2d_79
# 259 conv2d_80
# 260 conv2d_83
# 261 conv2d_84
# 262 average_pooling2d_8
# 263 conv2d_77
# 264 batch_normalization_79
# 265 batch_normalization_80
# 266 batch_normalization_83
# 267 batch_normalization_84
# 268 conv2d_85
# 269 batch_normalization_77
# 270 activation_455
# 271 activation_456
# 272 activation_459
# 273 activation_460
# 274 batch_normalization_85
# 275 activation_453
# 276 mixed9_0
# 277 concatenate_9
# 278 activation_461
# 279 mixed9
# 280 conv2d_90
# 281 batch_normalization_90
# 282 activation_466
# 283 conv2d_87
# 284 conv2d_91
# 285 batch_normalization_87
# 286 batch_normalization_91
# 287 activation_463
# 288 activation_467
# 289 conv2d_88
# 290 conv2d_89
# 291 conv2d_92
# 292 conv2d_93
# 293 average_pooling2d_9
# 294 conv2d_86
# 295 batch_normalization_88
# 296 batch_normalization_89
# 297 batch_normalization_92
# 298 batch_normalization_93
# 299 conv2d_94
# 300 batch_normalization_86
# 301 activation_464
# 302 activation_465
# 303 activation_468
# 304 activation_469
# 305 batch_normalization_94
# 306 activation_462
# 307 mixed9_1
# 308 concatenate_10
# 309 activation_470
# 310 mixed10

# %%
# we chose to train the top 2 inception blocks, i.e. we will freeze
# the first 249 layers and unfreeze the rest:
for layer in model.layers[:249]:
   layer.trainable = False
for layer in model.layers[249:]:
   layer.trainable = True

# %%
# we need to recompile the model for these modifications to take effect
# we use SGD with a low learning rate
from keras.optimizers import SGD
model.compile(optimizer=SGD(lr=0.0001, momentum=0.9), loss='categorical_crossentropy')

# %%
# we train our model again (this time fine-tuning the top 2 inception blocks
# alongside the top Dense layers
model.fit_generator(train_datagen.flow(X_train, y_train, batch_size=32),
                    epochs=20, validation_data= (X_test,y_test))
# Out:
# Epoch 1/20
# 52/52 [==============================] - 154s 3s/step - loss: 0.7318 - val_loss: 1.5169
# Epoch 2/20
# 52/52 [==============================] - 148s 3s/step - loss: 0.6320 - val_loss: 1.4414
# Epoch 3/20
# 52/52 [==============================] - 152s 3s/step - loss: 0.6119 - val_loss: 1.4505
# Epoch 4/20
# 52/52 [==============================] - 146s 3s/step - loss: 0.5942 - val_loss: 1.4227
# Epoch 5/20
# 52/52 [==============================] - 146s 3s/step - loss: 0.5963 - val_loss: 1.4173
# Epoch 6/20
# 52/52 [==============================] - 143s 3s/step - loss: 0.5664 - val_loss: 1.4421
# Epoch 7/20
# 52/52 [==============================] - 150s 3s/step - loss: 0.5530 - val_loss: 1.4715
# Epoch 8/20
# 52/52 [==============================] - 155s 3s/step - loss: 0.5536 - val_loss: 1.4975
# Epoch 9/20
# 52/52 [==============================] - 166s 3s/step - loss: 0.5412 - val_loss: 1.4742
# Epoch 10/20
# 52/52 [==============================] - 147s 3s/step - loss: 0.5446 - val_loss: 1.5339
# Epoch 11/20
# 52/52 [==============================] - 147s 3s/step - loss: 0.5607 - val_loss: 1.4750
# Epoch 12/20
# 52/52 [==============================] - 147s 3s/step - loss: 0.5129 - val_loss: 1.4779
# Epoch 13/20
# 52/52 [==============================] - 146s 3s/step - loss: 0.5350 - val_loss: 1.5035
# Epoch 14/20
# 52/52 [==============================] - 146s 3s/step - loss: 0.4957 - val_loss: 1.4727
# Epoch 15/20
# 52/52 [==============================] - 144s 3s/step - loss: 0.5316 - val_loss: 1.4403
# Epoch 16/20
# 52/52 [==============================] - 149s 3s/step - loss: 0.5241 - val_loss: 1.4363
# Epoch 17/20
# 52/52 [==============================] - 148s 3s/step - loss: 0.5304 - val_loss: 1.4982
# Epoch 18/20
# 52/52 [==============================] - 149s 3s/step - loss: 0.4957 - val_loss: 1.4621
# Epoch 19/20
# 52/52 [==============================] - 156s 3s/step - loss: 0.4577 - val_loss: 1.4617
# Epoch 20/20
# 52/52 [==============================] - 151s 3s/step - loss: 0.4748 - val_loss: 1.4656

# %% [markdown]
# После долгих попыток улучшить или даже достичь(ибо после наилучшего результата, что-либо я не делал, всё приводило в ухудшению результата), на kaggle у меня получилось достичь 0.827 точности. Считалось бы всё побыстрее, а то ну очень много времени на этом теряется
