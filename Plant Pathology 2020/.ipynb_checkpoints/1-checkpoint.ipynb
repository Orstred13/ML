# %%
from matplotlib import pyplot as plt
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout
import keras

import pandas as pd
# Out:
# Using TensorFlow backend.

# %%
img = plt.imread('images/Train_0.jpg')
print(img.shape)
plt.imshow(img)
# Out:
# (1365, 2048, 3)

# %%
test = pd.read_csv('test.csv')
train = pd.read_csv('train.csv')

# %%
train
# Out:
#         image_id  healthy  multiple_diseases  rust  scab
# 0        Train_0        0                  0     0     1
# 1        Train_1        0                  1     0     0
# 2        Train_2        1                  0     0     0
# 3        Train_3        0                  0     1     0
# 4        Train_4        1                  0     0     0
# ...          ...      ...                ...   ...   ...
# 1816  Train_1816        0                  0     0     1
# 1817  Train_1817        1                  0     0     0
# 1818  Train_1818        1                  0     0     0
# 1819  Train_1819        0                  0     1     0
# 1820  Train_1820        0                  0     0     1
#
# [1821 rows x 5 columns]

# %%
test.head()
# Out:
#   image_id
# 0   Test_0
# 1   Test_1
# 2   Test_2
# 3   Test_3
# 4   Test_4

# %%
sample_submission.head()
# Out:
#   image_id  healthy  multiple_diseases  rust  scab
# 0   Test_0     0.25               0.25  0.25  0.25
# 1   Test_1     0.25               0.25  0.25  0.25
# 2   Test_2     0.25               0.25  0.25  0.25
# 3   Test_3     0.25               0.25  0.25  0.25
# 4   Test_4     0.25               0.25  0.25  0.25

# %%
img
# Out:
# array([[[ 33,  51,  13],
#         [ 33,  51,  13],
#         [ 33,  51,  13],
#         ...,
#         [ 51,  61,  27],
#         [ 51,  61,  27],
#         [ 51,  61,  27]],
#
#        [[ 33,  51,  13],
#         [ 33,  51,  13],
#         [ 33,  51,  13],
#         ...,
#         [ 50,  60,  26],
#         [ 50,  60,  26],
#         [ 50,  60,  26]],
#
#        [[ 33,  51,  13],
#         [ 33,  51,  13],
#         [ 33,  51,  13],
#         ...,
#         [ 50,  60,  26],
#         [ 50,  60,  26],
#         [ 50,  60,  26]],
#
#        ...,
#
#        [[181, 167, 120],
#         [182, 168, 121],
#         [182, 168, 121],
#         ...,
#         [199, 206, 152],
#         [197, 202, 148],
#         [196, 201, 145]],
#
#        [[181, 167, 120],
#         [182, 168, 121],
#         [182, 168, 121],
#         ...,
#         [200, 207, 155],
#         [200, 204, 153],
#         [202, 206, 155]],
#
#        [[181, 167, 120],
#         [182, 168, 121],
#         [182, 168, 121],
# ...

# %%
train.sum(axis=0)
# Out:
# image_id             Train_0Train_1Train_2Train_3Train_4Train_5Trai...
# healthy                                                            516
# multiple_diseases                                                   91
# rust                                                               622
# scab                                                               592
# dtype: object

# %% [markdown]
# Тут проблема с multiple_diseases, нейронка будет плохо определять этот класс, как вариант можно как нагенерировать(поворотами и сдвигами) фотографий именно этого класса, но я не совсем понимаю, как это сделать

# %%
train_images = []
for name in train['image_id'] :
    path = 'images/'+name+'.jpg'
    image = plt.imread(path)
    train_images.append(image)

# %%
train_images[0].shape
# Out:
# (1365, 2048, 3)

# %%
X = np.ndarray(shape=(len(train_images),1365,2048,3),dtype=np.float32)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-5-8cbce552fa24> in <module>
# ----> 1 X = np.ndarray(shape=(len(train_images),1365,2048,3),dtype=np.float32)
#       2
#       3
#       4 for i,image in enumerate(train_images) :
#       5     X[i] = image
#
# MemoryError: Unable to allocate 56.9 GiB for an array with shape (1821, 1365, 2048, 3) and data type float32

# %% [markdown]
# Нуууууу, столько у меня места явно нет, поэтому можно попытаться уменьшить разрешения картинок

# %% [markdown]
# У pyplot я не нашёл, как можно изменить разрешение картинок, поэтому использую OpenCV

# %%
import cv2

# %%
train_images = []
img_size = 64
for name in train['image_id'] :
    path = 'images/'+name+'.jpg'
    image = plt.imread(path)
    image=cv2.resize(image,(img_size,img_size),interpolation=cv2.INTER_AREA)
    train_images.append(image)

# %%
train_images[1].shape
# Out:
# (64, 64, 3)

# %%
X = np.ndarray(shape=(len(train_images),img_size,img_size,3),dtype=np.float32)

# %%
for i,image in enumerate(train_images) :
    X[i] = image

# %%
X = X/255

# %%
plt.imshow(X[0])

# %%
X.shape
# Out:
# (1821, 64, 64, 3)

# %% [markdown]
# Ура, не знаю почему, но именно эта часть у меня заняла 1.5 дня...

# %% [markdown]
# Теперь быстренько с тестовыми разбираемся

# %%
test_images = []
for name in test['image_id'] :
    path = 'images/'+name+'.jpg'
    image = plt.imread(path)
    image=cv2.resize(image,(img_size,img_size),interpolation=cv2.INTER_AREA)
    test_images.append(image)

# %%
y_train = train.drop('image_id',axis=1)
y_train = np.array(y_train)
y_train.shape
# Out:
# (1821, 4)

# %%
X_test_kaggle = np.ndarray(shape=(len(test_images),img_size,img_size,3),dtype=np.float32)

for i,image in enumerate(test_images) :
    X_test_kaggle[i]=image

X_test_kaggle = X_test_kaggle / 255

# %%
X_test_kaggle.shape
# Out:
# (1821, 64, 64, 3)

# %%
plt.imshow(X_test_kaggle[3])

# %%
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization

# %%
model = Sequential()
   
    
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 3), padding='same'))
model.add(Conv2D(32,kernel_size=(3,3),padding='same',activation='relu'))
model.add(Conv2D(32,kernel_size=(3,3),padding='same',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))    
model.add(Dropout(0.3))
    

model.add(Conv2D(64,kernel_size=(3,3),padding='same',activation='relu'))
model.add(Conv2D(64,kernel_size=(3,3),padding='same',activation='relu'))
model.add(Conv2D(64,kernel_size=(3,3),padding='same',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))   
model.add(Dropout(0.3))


model.add(Conv2D(128,kernel_size=(3,3),padding='same',activation='relu'))
model.add(Conv2D(128,kernel_size=(3,3),padding='same',activation='relu'))
model.add(Conv2D(128,kernel_size=(3,3),padding='same',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))    
model.add(Dropout(0.3))

#ну я уже не знаю, что делать, попытаюсь добавить ещё один слой

model.add(Conv2D(256,kernel_size=(3,3),padding='same',activation='relu'))
model.add(Conv2D(256,kernel_size=(3,3),padding='same',activation='relu'))
model.add(Conv2D(256,kernel_size=(3,3),padding='same',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))    
model.add(Dropout(0.3))

model.add(Flatten())
model.add(Dense(512,activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(32,activation='relu'))
model.add(Dense(4,activation='softmax'))


model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_10 (Conv2D)           (None, 64, 64, 64)        1792
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 64, 64, 64)        36928
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 64, 64, 64)        36928
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 64, 64, 64)        256
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 32, 32, 32)        18464
# ...

# %%
predict = model.predict(X_test_kaggle)

# %%
df_pred  = pd.DataFrame(predict, columns = ['healthy','multiple_diseases','rust','scab'])
results = {'image_id' : test.image_id,
            'healthy' : df_pred.healthy,
            'multiple_diseases' : df_pred.multiple_diseases,
            'rust' : df_pred.rust,
            'scab' : df_pred.scab
          }
df_results_cnn = pd.DataFrame(results)
df_results_cnn.to_csv('submission.csv',index=False)

# %% [markdown]
# Ну, результат получился не самым лучшим, попытаемся улучшить всё это дело

# %%
X = (X - X.mean()) / X.std() #Внезапно вспомнил про нормализацию

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(
      rotation_range=60,
      width_shift_range=0.2,
      height_shift_range=0.2,
      horizontal_flip=True,
      fill_mode='nearest')

# %%
train_datagen.fit(X)

# %%
model.fit_generator(train_datagen.flow(X_train, y_train, batch_size=32),
                    steps_per_epoch=len(X) / 32, epochs=40, validation_data= (X_test,y_test))
# Out:
# Epoch 1/40
# 57/56 [==============================] - 52s 916ms/step - loss: 1.5752 - accuracy: 0.3225 - val_loss: 1.3026 - val_accuracy: 0.3534
# Epoch 2/40
# 57/56 [==============================] - 51s 893ms/step - loss: 1.3443 - accuracy: 0.3181 - val_loss: 1.2576 - val_accuracy: 0.3753
# Epoch 3/40
# 57/56 [==============================] - 53s 936ms/step - loss: 1.2637 - accuracy: 0.3470 - val_loss: 1.2423 - val_accuracy: 0.3370
# Epoch 4/40
# 57/56 [==============================] - 50s 885ms/step - loss: 1.2549 - accuracy: 0.3700 - val_loss: 1.2502 - val_accuracy: 0.3726
# Epoch 5/40
# 57/56 [==============================] - 51s 901ms/step - loss: 1.2461 - accuracy: 0.3612 - val_loss: 1.2300 - val_accuracy: 0.4164
# Epoch 6/40
# 57/56 [==============================] - 52s 906ms/step - loss: 1.2279 - accuracy: 0.3872 - val_loss: 1.1807 - val_accuracy: 0.4575
# Epoch 7/40
# ...

# %% [markdown]
# Ну я уже не знаю, что делать, добавлю валидацию

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_train, test_size=0.2, random_state=42)
